# %% [markdown]
# ## 0.2. Using the code

# %%
cd code

# %%
# %run nsfg.py

# %% [markdown]
# # Exploratory data analysis
# ## 1.4 DataFrames

# %%
import nsfg
df = nsfg.ReadFemPreg()
df

# %%
df.columns

# %%
df.columns[1]

# %%
pregordr = df['pregordr']
type(pregordr)

# %%
pregordr

# %%
pregordr[0]

# %%
pregordr[2:5]

# %%
pregordr = df.pregordr

# %% [markdown]
# ## 1.6 Transformation

# %%
import numpy as np
np.nan / 100.0

# %% [markdown]
# ## 1.7 Validation

# %%
df.outcome.value_counts().sort_index()

# %%
df.birthwgt_lb.value_counts(sort=False)

# %% [markdown]
# ## 1.8 Interpretation

# %%
caseid = 10229
preg_map = nsfg.MakePregMap(df)
indices = preg_map[caseid]
df.outcome[indices].values

# %% [markdown]
# ## 2.2 Representing histograms

# %%
import thinkstats2
hist = thinkstats2.Hist([1, 2, 2, 3, 5])
hist

# %%
for val in sorted(hist.Values()):
    print(val, hist.Freq(val))

# %%
for val, freq in hist.Items():
    print(val, freq)

# %%
import thinkplot
thinkplot.Hist(hist)
thinkplot.Show(xlabel='value', ylabel='frequency')

# %% [markdown]
# ## 2.4 NSFG variables

# %%
cd code
# Out:
# [WinError 2] Das System kann die angegebene Datei nicht finden: 'code'
# f:\GitKraken\ThinkStats2\code

# %%
import nsfg
import thinkstats2
import thinkplot

# %%
preg = nsfg.ReadFemPreg()
live = preg[preg.outcome == 1]

hist = thinkstats2.Hist(live.birthwgt_lb, label='birthwgt_lb')
thinkplot.Hist(hist)
thinkplot.Show(xlabel='pounds', ylabel='frequency')
